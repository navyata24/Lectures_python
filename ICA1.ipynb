# %%
# SET 19

#Q1

marks=int(input("Enter marks: "))
marks += 5
print("after 5 marks bonus:", marks)
marks -= 2
print("after 2 marks penalty:",marks)
# Out:
# Enter marks: 35
# after 5 marks bonus: 40
# after 2 marks penalty: 38

# %%
#Q2

word=str(input("Enter a word: "))
word1=str(input("Enter other word: "))
print(word+" "+word1)
# Out:
# Enter a word: apple
# Enter other word: cat
# apple cat

# %%
#Q3

lst=[1,2,3,4,5]
lst[0] , lst[-1]=lst[-1],lst[0]
print(lst)
# Out:
# [5, 2, 3, 4, 1]

# %%
#Q4

print(type(set()))
print(type({}))

# {} is considered a dictionary in Python by default whereas an empty set is created using set().
# Out:
# <class 'set'>
# <class 'dict'>
