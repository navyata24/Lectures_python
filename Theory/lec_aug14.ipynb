# %%
phone={ "Brand":"One plus",
       "Operating System":"OxygenOS 16",
        "RAM Memory Installed Size":["6GB" , "4GB"],
        "CPU Speed":"2.4GHz",
        "Memory Storage Capacity":"128GB",
        "Size":["6GB+128GB" , "4GB"],
        "Price":["₹24,998" , "23,998"]}

print(f"{phone['Brand']} {phone['Operating System']} {phone['RAM Memory Installed Size'][0]}   {phone['CPU Speed']}  {phone['Memory Storage Capacity']} {phone['Size'][0]} {phone['Price'][0]}")
# Out:
# One plus OxygenOS 16 6GB   2.4GHz  128GB 6GB+128GB ₹24,998

# %%
iphone = {
"iphone 15": {"os": "ios", "RAM Memory": "128GB"},
"iphone 17": {"os": "ios", "RAM Memory": "264GB"},
}
print(iphone["iphone 15"]["os"])
iphone["iphone 16"] = {"os": "ios", "RAM Memory": "128GB"}
print(len(iphone))
for key,value in iphone["iphone 15"].items():
  {
    print(key,value)
  }
# Out:
# ios
# 3
# os ios
# RAM Memory 128GB
