# %%
student={
    "college":"Nilkamal School Of Mathematics,Applied Statistics & Analytics",
    "name":"Navyata Bhatt","course":"BSC AMC","DOB":"24.08.2007",
    "Blood Group":"B+","Contact":"9578204720",
    "SAP ID":"86122600033"
}
print(student.keys())
print(student.values())
print(student.items())
print(student.get("college",0))
print(student.pop("DOB"))
print(student.update({"Blood Group":"A+"}))
for key,value in student.items():
    print(key,"->",value)
# Out:
# dict_keys(['college', 'name', 'course', 'DOB', 'Blood Group', 'Contact', 'SAP ID'])
# dict_values(['Nilkamal School Of Mathematics,Applied Statistics & Analytics', 'Navyata Bhatt', 'BSC AMC', '24.08.2007', 'B+', '9578204720', '86122600033'])
# dict_items([('college', 'Nilkamal School Of Mathematics,Applied Statistics & Analytics'), ('name', 'Navyata Bhatt'), ('course', 'BSC AMC'), ('DOB', '24.08.2007'), ('Blood Group', 'B+'), ('Contact', '9578204720'), ('SAP ID', '86122600033')])
# Nilkamal School Of Mathematics,Applied Statistics & Analytics
# 24.08.2007
# None
# college -> Nilkamal School Of Mathematics,Applied Statistics & Analytics
# name -> Navyata Bhatt
# course -> BSC AMC
# Blood Group -> A+
# Contact -> 9578204720
# SAP ID -> 86122600033

# %%
#Sets
A={1,2,3,4}
B={3,4,5,6}

print(A|B)
print(A&B)
print(A-B)
# Out:
# {1, 2, 3, 4, 5, 6}
# {3, 4}
# {1, 2}

# %%
age=25
print(18<=age<=60)
# Out:
# True
